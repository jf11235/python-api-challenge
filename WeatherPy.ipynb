# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 639

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'metric'

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"{url}appid={weather_api_key}&units={units}&q={city}"
    print(city_url)
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    response = requests.get(city_url).json()
    print(json.dumps(response, indent=4,sort_keys=True))
    try:
        # Parse the JSON and retrieve data
        city_weather = response['weather']["description"]

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = response['coord']['lat']
        city_lng = response['coord']['lon']
        city_max_temp = response['main']['temp_max']
        city_humidity = response['main']["humidity"]
        city_clouds = response['clouds']['all']
        city_wind = response['wind']['speed']
        city_country = response['sys']["country"]
        city_date = response['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=vardo
# Processing Record 1 of Set 1 | vardo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.3705,
#         "lon": 31.1107
#     },
#     "dt": 1675175167,
#     "id": 777019,
#     "main": {
#         "feels_like": -2.79,
#         "humidity": 93,
#         "pressure": 979,
#         "temp": 0.99,
#         "temp_max": 0.99,
#         "temp_min": 0.99
#     },
#     "name": "Vard\u00f8",
#     "snow": {
#         "1h": 0.46
#     },
#     "sys": {
#         "country": "NO",
#         "id": 1666,
#         "sunrise": 1675151800,
#         "sunset": 1675167662,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 3.6
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=bluff
# Processing Record 2 of Set 1 | bluff
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.6,
#         "lon": 168.3333
#     },
#     "dt": 1675174728,
#     "id": 2206939,
#     "main": {
#         "feels_like": 15.56,
#         "grnd_level": 1012,
#         "humidity": 97,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 15.43,
#         "temp_max": 15.43,
#         "temp_min": 15.43
#     },
#     "name": "Bluff",
#     "rain": {
#         "1h": 0.22
#     },
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1675186661,
#         "sunset": 1675239747
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 165,
#         "gust": 3.77,
#         "speed": 2.79
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=hobyo
# Processing Record 3 of Set 1 | hobyo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 2
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.3505,
#         "lon": 48.5268
#     },
#     "dt": 1675175168,
#     "id": 57000,
#     "main": {
#         "feels_like": 25.95,
#         "grnd_level": 1011,
#         "humidity": 67,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 25.95,
#         "temp_max": 25.95,
#         "temp_min": 25.95
#     },
#     "name": "Hobyo",
#     "sys": {
#         "country": "SO",
#         "sunrise": 1675134147,
#         "sunset": 1675176955
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 55,
#         "gust": 10.46,
#         "speed": 9.84
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=lumsden
# Processing Record 4 of Set 1 | lumsden
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.6501,
#         "lon": -104.8678
#     },
#     "dt": 1675175169,
#     "id": 6061979,
#     "main": {
#         "feels_like": -21.47,
#         "grnd_level": 957,
#         "humidity": 98,
#         "pressure": 1023,
#         "sea_level": 1023,
#         "temp": -21.47,
#         "temp_max": -21.47,
#         "temp_min": -21.47
#     },
#     "name": "Lumsden",
#     "sys": {
#         "country": "CA",
#         "id": 903,
#         "sunrise": 1675175803,
#         "sunset": 1675208937,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 195,
#         "gust": 1.27,
#         "speed": 1.27
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=guerrero negro
# Processing Record 5 of Set 1 | guerrero negro
# {
#     "base": "stations",
#     "clouds": {
#         "all": 6
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 27.9769,
#         "lon": -114.0611
#     },
#     "dt": 1675174792,
#     "id": 4021858,
#     "main": {
#         "feels_like": 12.14,
#         "grnd_level": 1016,
#         "humidity": 83,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 12.65,
#         "temp_max": 12.65,
#         "temp_min": 12.65
#     },
#     "name": "Guerrero Negro",
#     "rain": {
#         "1h": 0.13
#     },
#     "sys": {
#         "country": "MX",
#         "sunrise": 1675175034,
#         "sunset": 1675214119
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 302,
#         "gust": 3.78,
#         "speed": 3
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=kapaa
# Processing Record 6 of Set 1 | kapaa
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.0752,
#         "lon": -159.319
#     },
#     "dt": 1675174774,
#     "id": 5848280,
#     "main": {
#         "feels_like": 19.88,
#         "humidity": 91,
#         "pressure": 1012,
#         "temp": 19.5,
#         "temp_max": 19.55,
#         "temp_min": 19.5
#     },
#     "name": "Kapaa",
#     "rain": {
#         "1h": 0.14
#     },
#     "sys": {
#         "country": "US",
#         "id": 2005473,
#         "sunrise": 1675185359,
#         "sunset": 1675225520,
#         "type": 2
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 148,
#         "gust": 0.89,
#         "speed": 0.45
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=hithadhoo
# Processing Record 7 of Set 1 | hithadhoo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.6,
#         "lon": 73.0833
#     },
#     "dt": 1675174767,
#     "id": 1282256,
#     "main": {
#         "feels_like": 30.15,
#         "grnd_level": 1010,
#         "humidity": 76,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 27.38,
#         "temp_max": 27.38,
#         "temp_min": 27.38
#     },
#     "name": "Hithadhoo",
#     "sys": {
#         "country": "MV",
#         "sunrise": 1675127802,
#         "sunset": 1675171511
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 296,
#         "gust": 7.05,
#         "speed": 6.35
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=port alfred
# Processing Record 8 of Set 1 | port alfred
# {
#     "base": "stations",
#     "clouds": {
#         "all": 32
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.5906,
#         "lon": 26.891
#     },
#     "dt": 1675174751,
#     "id": 964432,
#     "main": {
#         "feels_like": 25.78,
#         "humidity": 81,
#         "pressure": 1012,
#         "temp": 25.1,
#         "temp_max": 25.1,
#         "temp_min": 25.1
#     },
#     "name": "Port Alfred",
#     "sys": {
#         "country": "ZA",
#         "id": 2072861,
#         "sunrise": 1675135989,
#         "sunset": 1675185500,
#         "type": 2
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 74,
#         "gust": 9.39,
#         "speed": 4.47
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=buta
# Processing Record 9 of Set 1 | buta
# {
#     "base": "stations",
#     "clouds": {
#         "all": 21
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 2.7858,
#         "lon": 24.73
#     },
#     "dt": 1675175170,
#     "id": 217570,
#     "main": {
#         "feels_like": 36.42,
#         "grnd_level": 961,
#         "humidity": 19,
#         "pressure": 1004,
#         "sea_level": 1004,
#         "temp": 37.98,
#         "temp_max": 37.98,
#         "temp_min": 37.98
#     },
#     "name": "Buta",
#     "sys": {
#         "country": "CD",
#         "sunrise": 1675139664,
#         "sunset": 1675182861
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 278,
#         "gust": 4.4,
#         "speed": 0.07
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=sioux lookout
# Processing Record 10 of Set 1 | sioux lookout
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.1001,
#         "lon": -91.917
#     },
#     "dt": 1675175023,
#     "id": 6148373,
#     "main": {
#         "feels_like": -33.96,
#         "humidity": 76,
#         "pressure": 1015,
#         "temp": -26.96,
#         "temp_max": -26.96,
#         "temp_min": -26.96
#     },
#     "name": "Sioux Lookout",
#     "sys": {
#         "country": "CA",
#         "id": 979,
#         "sunrise": 1675172593,
#         "sunset": 1675205930,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 2.06
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=luderitz
# Processing Record 11 of Set 1 | luderitz
# {
#     "base": "stations",
#     "clouds": {
#         "all": 4
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -26.6481,
#         "lon": 15.1594
#     },
#     "dt": 1675174703,
#     "id": 3355672,
#     "main": {
#         "feels_like": 21.71,
#         "grnd_level": 1008,
#         "humidity": 59,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 21.92,
#         "temp_max": 21.92,
#         "temp_min": 21.92
#     },
#     "name": "L\u00fcderitz",
#     "sys": {
#         "country": "NA",
#         "sunrise": 1675139541,
#         "sunset": 1675187579
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 207,
#         "gust": 5.45,
#         "speed": 5.38
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=jining
# Processing Record 12 of Set 1 | jining
# {
#     "base": "stations",
#     "clouds": {
#         "all": 19
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 35.405,
#         "lon": 116.5814
#     },
#     "dt": 1675175171,
#     "id": 1805518,
#     "main": {
#         "feels_like": 5.29,
#         "grnd_level": 1012,
#         "humidity": 52,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 6.94,
#         "temp_max": 6.94,
#         "temp_min": 6.94
#     },
#     "name": "Jining",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1675120472,
#         "sunset": 1675157960
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 17,
#         "gust": 2.37,
#         "speed": 2.39
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=thompson
# Processing Record 13 of Set 1 | thompson
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.7435,
#         "lon": -97.8558
#     },
#     "dt": 1675174839,
#     "id": 6165406,
#     "main": {
#         "feels_like": -35.91,
#         "humidity": 68,
#         "pressure": 1014,
#         "temp": -35.91,
#         "temp_max": -35.91,
#         "temp_min": -35.91
#     },
#     "name": "Thompson",
#     "sys": {
#         "country": "CA",
#         "id": 935,
#         "sunrise": 1675175243,
#         "sunset": 1675206130,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 1.03
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=wajima
# Processing Record 14 of Set 1 | wajima
# {
#     "base": "stations",
#     "clouds": {
#         "all": 94
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.4,
#         "lon": 136.9
#     },
#     "dt": 1675175172,
#     "id": 1848976,
#     "main": {
#         "feels_like": 1.53,
#         "grnd_level": 1016,
#         "humidity": 71,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 6.5,
#         "temp_max": 6.5,
#         "temp_min": 6.5
#     },
#     "name": "Wajima",
#     "rain": {
#         "1h": 0.11
#     },
#     "sys": {
#         "country": "JP",
#         "sunrise": 1675115831,
#         "sunset": 1675152847
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "gust": 12.64,
#         "speed": 10.18
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=taolanaro
# Processing Record 15 of Set 1 | taolanaro
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=kavaratti
# Processing Record 16 of Set 1 | kavaratti
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 10.5669,
#         "lon": 72.642
#     },
#     "dt": 1675174961,
#     "id": 1267390,
#     "main": {
#         "feels_like": 28.52,
#         "grnd_level": 1009,
#         "humidity": 72,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 26.71,
#         "temp_max": 26.71,
#         "temp_min": 26.71
#     },
#     "name": "Kavaratti",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1675128760,
#         "sunset": 1675170765
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 341,
#         "gust": 5.56,
#         "speed": 5.63
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=bredasdorp
# Processing Record 17 of Set 1 | bredasdorp
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.5322,
#         "lon": 20.0403
#     },
#     "dt": 1675175173,
#     "id": 1015776,
#     "main": {
#         "feels_like": 26.11,
#         "grnd_level": 1003,
#         "humidity": 55,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 26.11,
#         "temp_max": 26.11,
#         "temp_min": 26.11
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1675137524,
#         "sunset": 1675187253
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "gust": 6.25,
#         "speed": 6.94
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=conceicao do mato dentro
# Processing Record 18 of Set 1 | conceicao do mato dentro
# {
#     "base": "stations",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -19.0372,
#         "lon": -43.425
#     },
#     "dt": 1675175174,
#     "id": 3465745,
#     "main": {
#         "feels_like": 25.37,
#         "grnd_level": 937,
#         "humidity": 66,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 25.08,
#         "temp_max": 25.08,
#         "temp_min": 25.08
#     },
#     "name": "Concei\u00e7\u00e3o do Mato Dentro",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1675154307,
#         "sunset": 1675200937
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 53,
#         "gust": 2.73,
#         "speed": 1.86
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=umaria
# Processing Record 19 of Set 1 | umaria
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 23.5333,
#         "lon": 80.8333
#     },
#     "dt": 1675175174,
#     "id": 1253863,
#     "main": {
#         "feels_like": 18.24,
#         "grnd_level": 963,
#         "humidity": 52,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 18.93,
#         "temp_max": 18.93,
#         "temp_min": 18.93
#     },
#     "name": "Umaria",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1675127864,
#         "sunset": 1675167729
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "gust": 9.07,
#         "speed": 3.12
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=borogontsy
# Processing Record 20 of Set 1 | borogontsy
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.6683,
#         "lon": 131.1683
#     },
#     "dt": 1675175175,
#     "id": 2026160,
#     "main": {
#         "feels_like": -46.55,
#         "grnd_level": 1001,
#         "humidity": 98,
#         "pressure": 1020,
#         "sea_level": 1020,
#         "temp": -39.55,
#         "temp_max": -39.55,
#         "temp_min": -39.55
#     },
#     "name": "Borogontsy",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1675122613,
#         "sunset": 1675148816
#     },
#     "timezone": 32400,
#     "visibility": 5448,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 271,
#         "gust": 4.73,
#         "speed": 1.75
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=ewa beach
# Processing Record 21 of Set 1 | ewa beach
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.3156,
#         "lon": -158.0072
#     },
#     "dt": 1675174733,
#     "id": 5855051,
#     "main": {
#         "feels_like": 21.3,
#         "humidity": 88,
#         "pressure": 1013,
#         "temp": 20.86,
#         "temp_max": 21.34,
#         "temp_min": 19.65
#     },
#     "name": "\u2018Ewa Beach",
#     "rain": {
#         "1h": 0.15
#     },
#     "sys": {
#         "country": "US",
#         "id": 7868,
#         "sunrise": 1675184979,
#         "sunset": 1675225270,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 1.54
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=mutoko
# Processing Record 22 of Set 1 | mutoko
# {
#     "base": "stations",
#     "clouds": {
#         "all": 91
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -17.397,
#         "lon": 32.2268
#     },
#     "dt": 1675175176,
#     "id": 884927,
#     "main": {
#         "feels_like": 24.87,
#         "grnd_level": 874,
#         "humidity": 52,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 24.96,
#         "temp_max": 24.96,
#         "temp_min": 24.96
#     },
#     "name": "Mutoko",
#     "sys": {
#         "country": "ZW",
#         "sunrise": 1675136283,
#         "sunset": 1675182643
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 63,
#         "gust": 4.56,
#         "speed": 3.01
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=aklavik
# Processing Record 23 of Set 1 | aklavik
# {
#     "base": "stations",
#     "clouds": {
#         "all": 72
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 68.2191,
#         "lon": -135.0107
#     },
#     "dt": 1675174795,
#     "id": 5882953,
#     "main": {
#         "feels_like": -35.47,
#         "grnd_level": 1032,
#         "humidity": 100,
#         "pressure": 1033,
#         "sea_level": 1033,
#         "temp": -35.47,
#         "temp_max": -35.47,
#         "temp_min": -35.47
#     },
#     "name": "Aklavik",
#     "sys": {
#         "country": "CA",
#         "sunrise": 1675189491,
#         "sunset": 1675209719
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 309,
#         "gust": 0.67,
#         "speed": 0.63
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=manaus
# Processing Record 24 of Set 1 | manaus
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -3.1019,
#         "lon": -60.025
#     },
#     "dt": 1675174933,
#     "id": 3663517,
#     "main": {
#         "feels_like": 26.27,
#         "humidity": 89,
#         "pressure": 1013,
#         "temp": 26.27,
#         "temp_max": 26.28,
#         "temp_min": 26.27
#     },
#     "name": "Manaus",
#     "sys": {
#         "country": "BR",
#         "id": 8412,
#         "sunrise": 1675159563,
#         "sunset": 1675203649,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 3.09
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=yellowknife
# Processing Record 25 of Set 1 | yellowknife
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.456,
#         "lon": -114.3525
#     },
#     "dt": 1675174766,
#     "id": 6185377,
#     "main": {
#         "feels_like": -44.71,
#         "humidity": 67,
#         "pressure": 1017,
#         "temp": -37.71,
#         "temp_max": -36.36,
#         "temp_min": -37.71
#     },
#     "name": "Yellowknife",
#     "sys": {
#         "country": "CA",
#         "id": 1007,
#         "sunrise": 1675181340,
#         "sunset": 1675207953,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 300,
#         "speed": 3.09
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=sheregesh
# Processing Record 26 of Set 1 | sheregesh
# {
#     "base": "stations",
#     "clouds": {
#         "all": 89
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 52.9209,
#         "lon": 87.9869
#     },
#     "dt": 1675175177,
#     "id": 1492252,
#     "main": {
#         "feels_like": -15.94,
#         "grnd_level": 955,
#         "humidity": 98,
#         "pressure": 1034,
#         "sea_level": 1034,
#         "temp": -15.94,
#         "temp_max": -15.94,
#         "temp_min": -15.94
#     },
#     "name": "Sheregesh",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1675130031,
#         "sunset": 1675162128
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 117,
#         "gust": 0.92,
#         "speed": 0.95
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=vaini
# Processing Record 27 of Set 1 | vaini
# {
#     "base": "stations",
#     "clouds": {
#         "all": 69
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2,
#         "lon": -175.2
#     },
#     "dt": 1675174783,
#     "id": 4032243,
#     "main": {
#         "feels_like": 30.44,
#         "grnd_level": 1005,
#         "humidity": 79,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 27.36,
#         "temp_max": 27.36,
#         "temp_min": 27.36
#     },
#     "name": "Vaini",
#     "rain": {
#         "1h": 0.48
#     },
#     "sys": {
#         "country": "TO",
#         "sunrise": 1675272196,
#         "sunset": 1675319125
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 91,
#         "gust": 7.62,
#         "speed": 7.38
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=avarua
# Processing Record 28 of Set 1 | avarua
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2078,
#         "lon": -159.775
#     },
#     "dt": 1675174761,
#     "id": 4035715,
#     "main": {
#         "feels_like": 25.89,
#         "humidity": 88,
#         "pressure": 1010,
#         "temp": 25.03,
#         "temp_max": 25.03,
#         "temp_min": 25.03
#     },
#     "name": "Avarua",
#     "rain": {
#         "1h": 1.22
#     },
#     "sys": {
#         "country": "CK",
#         "id": 7271,
#         "sunrise": 1675182053,
#         "sunset": 1675229045,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10n",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 240,
#         "speed": 3.6
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=punta arenas
# Processing Record 29 of Set 1 | punta arenas
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.9167
#     },
#     "dt": 1675174763,
#     "id": 3874787,
#     "main": {
#         "feels_like": 10.66,
#         "humidity": 58,
#         "pressure": 1011,
#         "temp": 11.9,
#         "temp_max": 12.06,
#         "temp_min": 11.73
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1675156298,
#         "sunset": 1675212143,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 300,
#         "speed": 12.86
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=basco
# Processing Record 30 of Set 1 | basco
# {
#     "base": "stations",
#     "clouds": {
#         "all": 5
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 20.4487,
#         "lon": 121.9702
#     },
#     "dt": 1675175179,
#     "id": 1726449,
#     "main": {
#         "feels_like": 23.25,
#         "grnd_level": 1013,
#         "humidity": 66,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 23.16,
#         "temp_max": 23.16,
#         "temp_min": 23.16
#     },
#     "name": "Basco",
#     "sys": {
#         "country": "PH",
#         "sunrise": 1675117724,
#         "sunset": 1675158121
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 122,
#         "gust": 10.62,
#         "speed": 10.13
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=saint-philippe
# Processing Record 31 of Set 1 | saint-philippe
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.3585,
#         "lon": 55.7679
#     },
#     "dt": 1675174753,
#     "id": 935215,
#     "main": {
#         "feels_like": 33.71,
#         "grnd_level": 1008,
#         "humidity": 78,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 28.77,
#         "temp_max": 28.77,
#         "temp_min": 25.62
#     },
#     "name": "Saint-Philippe",
#     "sys": {
#         "country": "RE",
#         "id": 2127,
#         "sunrise": 1675130286,
#         "sunset": 1675177340,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 178,
#         "gust": 4.43,
#         "speed": 3.96
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=arani
# Processing Record 32 of Set 1 | arani
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 12.6667,
#         "lon": 79.2833
#     },
#     "dt": 1675175180,
#     "id": 1278454,
#     "main": {
#         "feels_like": 24.88,
#         "grnd_level": 994,
#         "humidity": 70,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 24.54,
#         "temp_max": 24.54,
#         "temp_min": 24.54
#     },
#     "name": "Arni",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1675127331,
#         "sunset": 1675169006
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 46,
#         "gust": 8.61,
#         "speed": 4.33
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=new norfolk
# Processing Record 33 of Set 1 | new norfolk
# {
#     "base": "stations",
#     "clouds": {
#         "all": 31
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.7826,
#         "lon": 147.0587
#     },
#     "dt": 1675174722,
#     "id": 2155415,
#     "main": {
#         "feels_like": 16.06,
#         "grnd_level": 997,
#         "humidity": 89,
#         "pressure": 1003,
#         "sea_level": 1003,
#         "temp": 16.07,
#         "temp_max": 16.72,
#         "temp_min": 16.07
#     },
#     "name": "New Norfolk",
#     "sys": {
#         "country": "AU",
#         "id": 2011256,
#         "sunrise": 1675192392,
#         "sunset": 1675244229,
#         "type": 2
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 276,
#         "gust": 1.15,
#         "speed": 1.24
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=louisbourg
# Processing Record 34 of Set 1 | louisbourg
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=camopi
# Processing Record 35 of Set 1 | camopi
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 3.1655,
#         "lon": -52.3158
#     },
#     "dt": 1675175181,
#     "id": 3382226,
#     "main": {
#         "feels_like": 26.19,
#         "grnd_level": 1001,
#         "humidity": 84,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 25.4,
#         "temp_max": 25.4,
#         "temp_min": 25.4
#     },
#     "name": "Camopi",
#     "sys": {
#         "country": "GF",
#         "sunrise": 1675158185,
#         "sunset": 1675201326
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 339,
#         "gust": 1.2,
#         "speed": 0.76
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=pulaski
# Processing Record 36 of Set 1 | pulaski
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 34.7668,
#         "lon": -92.3001
#     },
#     "dt": 1675175181,
#     "id": 4127619,
#     "main": {
#         "feels_like": -8.05,
#         "humidity": 90,
#         "pressure": 1029,
#         "temp": -3.05,
#         "temp_max": -1.84,
#         "temp_min": -4.34
#     },
#     "name": "Pulaski",
#     "sys": {
#         "country": "US",
#         "id": 47703,
#         "sunrise": 1675170508,
#         "sunset": 1675208199,
#         "type": 2
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 20,
#         "gust": 7.6,
#         "speed": 4.02
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=pisco
# Processing Record 37 of Set 1 | pisco
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -13.7,
#         "lon": -76.2167
#     },
#     "dt": 1675174717,
#     "id": 3932145,
#     "main": {
#         "feels_like": 25.63,
#         "humidity": 78,
#         "pressure": 1012,
#         "temp": 25.03,
#         "temp_max": 25.03,
#         "temp_min": 22.79
#     },
#     "name": "Pisco",
#     "sys": {
#         "country": "PE",
#         "id": 8691,
#         "sunrise": 1675162625,
#         "sunset": 1675208360,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 7000,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50d",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 1.54
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=sambava
# Processing Record 38 of Set 1 | sambava
# {
#     "base": "stations",
#     "clouds": {
#         "all": 7
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -14.2667,
#         "lon": 50.1667
#     },
#     "dt": 1675175183,
#     "id": 1056899,
#     "main": {
#         "feels_like": 32.31,
#         "grnd_level": 1009,
#         "humidity": 77,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 28.28,
#         "temp_max": 28.28,
#         "temp_min": 28.28
#     },
#     "name": "Sambava",
#     "rain": {
#         "1h": 0.19
#     },
#     "sys": {
#         "country": "MG",
#         "sunrise": 1675132237,
#         "sunset": 1675178078
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 135,
#         "gust": 5.43,
#         "speed": 3.58
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=chokurdakh
# Processing Record 39 of Set 1 | chokurdakh
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.6333,
#         "lon": 147.9167
#     },
#     "dt": 1675174886,
#     "id": 2126123,
#     "main": {
#         "feels_like": -17.92,
#         "grnd_level": 995,
#         "humidity": 95,
#         "pressure": 999,
#         "sea_level": 999,
#         "temp": -10.98,
#         "temp_max": -10.98,
#         "temp_min": -10.98
#     },
#     "name": "Chokurdakh",
#     "snow": {
#         "1h": 0.14
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1675210228,
#         "sunset": 1675225981
#     },
#     "timezone": 39600,
#     "visibility": 420,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 67,
#         "gust": 7.59,
#         "speed": 4.16
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=lebu
# Processing Record 40 of Set 1 | lebu
# {
#     "base": "stations",
#     "clouds": {
#         "all": 2
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -37.6167,
#         "lon": -73.65
#     },
#     "dt": 1675174711,
#     "id": 3883457,
#     "main": {
#         "feels_like": 14.64,
#         "grnd_level": 1010,
#         "humidity": 60,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 15.47,
#         "temp_max": 15.47,
#         "temp_min": 15.47
#     },
#     "name": "Lebu",
#     "sys": {
#         "country": "CL",
#         "sunrise": 1675159649,
#         "sunset": 1675210105
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 187,
#         "gust": 11.07,
#         "speed": 8.48
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=saint george
# Processing Record 41 of Set 1 | saint george
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.1041,
#         "lon": -113.5841
#     },
#     "dt": 1675174885,
#     "id": 5546220,
#     "main": {
#         "feels_like": -10.32,
#         "humidity": 68,
#         "pressure": 1024,
#         "temp": -6.67,
#         "temp_max": -6.67,
#         "temp_min": -6.67
#     },
#     "name": "Saint George",
#     "sys": {
#         "country": "US",
#         "id": 5832,
#         "sunrise": 1675175879,
#         "sunset": 1675213044,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 2.06
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=saleaula
# Processing Record 42 of Set 1 | saleaula
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=katsuura
# Processing Record 43 of Set 1 | katsuura
# {
#     "base": "stations",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 35.1333,
#         "lon": 140.3
#     },
#     "dt": 1675174803,
#     "id": 2112309,
#     "main": {
#         "feels_like": 5.29,
#         "grnd_level": 1019,
#         "humidity": 61,
#         "pressure": 1019,
#         "sea_level": 1019,
#         "temp": 5.29,
#         "temp_max": 5.29,
#         "temp_min": 5.29
#     },
#     "name": "Katsuura",
#     "sys": {
#         "country": "JP",
#         "sunrise": 1675114752,
#         "sunset": 1675152294
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 86,
#         "gust": 1.48,
#         "speed": 0.88
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=jiaojiang
# Processing Record 44 of Set 1 | jiaojiang
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.6803,
#         "lon": 121.4428
#     },
#     "dt": 1675175184,
#     "id": 1809061,
#     "main": {
#         "feels_like": 11.14,
#         "grnd_level": 1016,
#         "humidity": 86,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 11.67,
#         "temp_max": 11.67,
#         "temp_min": 11.67
#     },
#     "name": "Jiaojiang",
#     "sys": {
#         "country": "CN",
#         "id": 2016515,
#         "sunrise": 1675118600,
#         "sunset": 1675157498,
#         "type": 2
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 238,
#         "gust": 1.9,
#         "speed": 1.89
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=saskylakh
# Processing Record 45 of Set 1 | saskylakh
# {
#     "base": "stations",
#     "clouds": {
#         "all": 89
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.9167,
#         "lon": 114.0833
#     },
#     "dt": 1675174828,
#     "id": 2017155,
#     "main": {
#         "feels_like": -49.66,
#         "grnd_level": 1028,
#         "humidity": 100,
#         "pressure": 1029,
#         "sea_level": 1029,
#         "temp": -42.66,
#         "temp_max": -42.66,
#         "temp_min": -42.66
#     },
#     "name": "Saskylakh",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1675134270,
#         "sunset": 1675145361
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "gust": 1.31,
#         "speed": 1.43
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=ozinki
# Processing Record 46 of Set 1 | ozinki
# {
#     "base": "stations",
#     "clouds": {
#         "all": 10
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.1786,
#         "lon": 49.6769
#     },
#     "dt": 1675175185,
#     "id": 513329,
#     "main": {
#         "feels_like": -11.97,
#         "grnd_level": 1007,
#         "humidity": 93,
#         "pressure": 1019,
#         "sea_level": 1019,
#         "temp": -6.34,
#         "temp_max": -6.34,
#         "temp_min": -6.34
#     },
#     "name": "Ozinki",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1675138853,
#         "sunset": 1675171697
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 152,
#         "gust": 8.3,
#         "speed": 3.88
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=vao
# Processing Record 47 of Set 1 | vao
# {
#     "base": "stations",
#     "clouds": {
#         "all": 13
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -22.6667,
#         "lon": 167.4833
#     },
#     "dt": 1675174837,
#     "id": 2137773,
#     "main": {
#         "feels_like": 25.23,
#         "grnd_level": 998,
#         "humidity": 78,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 24.67,
#         "temp_max": 24.67,
#         "temp_min": 24.67
#     },
#     "name": "Vao",
#     "sys": {
#         "country": "NC",
#         "sunrise": 1675189784,
#         "sunset": 1675237032
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 88,
#         "gust": 4.26,
#         "speed": 4.4
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=esik
# Processing Record 48 of Set 1 | esik
# {
#     "base": "stations",
#     "clouds": {
#         "all": 73
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.3552,
#         "lon": 77.4525
#     },
#     "dt": 1675175186,
#     "id": 1523741,
#     "main": {
#         "feels_like": -13.57,
#         "grnd_level": 903,
#         "humidity": 79,
#         "pressure": 1028,
#         "sea_level": 1028,
#         "temp": -8.32,
#         "temp_max": -8.32,
#         "temp_min": -8.32
#     },
#     "name": "Esik",
#     "sys": {
#         "country": "KZ",
#         "id": 8818,
#         "sunrise": 1675130871,
#         "sunset": 1675166345,
#         "type": 1
#     },
#     "timezone": 21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "gust": 2.5,
#         "speed": 3.07
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=barrow
# Processing Record 49 of Set 1 | barrow
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.2906,
#         "lon": -156.7887
#     },
#     "dt": 1675174708,
#     "id": 5880054,
#     "main": {
#         "feels_like": -28.99,
#         "humidity": 71,
#         "pressure": 1027,
#         "temp": -21.99,
#         "temp_max": -21.99,
#         "temp_min": -21.99
#     },
#     "name": "Barrow",
#     "sys": {
#         "country": "US",
#         "id": 7649,
#         "sunrise": 1675197879,
# ...
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 20,
#         "speed": 6.69
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=podor
# Processing Record 23 of Set 13 | podor
# {
#     "base": "stations",
#     "clouds": {
#         "all": 4
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 16.6527,
#         "lon": -14.9587
#     },
#     "dt": 1675175505,
#     "id": 2245170,
#     "main": {
#         "feels_like": 28.81,
#         "grnd_level": 1010,
#         "humidity": 9,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 30.81,
#         "temp_max": 30.81,
#         "temp_min": 30.81
#     },
#     "name": "Podor",
#     "sys": {
#         "country": "MR",
#         "sunrise": 1675150266,
#         "sunset": 1675191313
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 42,
#         "gust": 1.76,
#         "speed": 2.05
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=woodward
# Processing Record 24 of Set 13 | woodward
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 36.4337,
#         "lon": -99.3904
#     },
#     "dt": 1675175505,
#     "id": 4556050,
#     "main": {
#         "feels_like": -14.32,
#         "humidity": 77,
#         "pressure": 1030,
#         "temp": -10.1,
#         "temp_max": -9.49,
#         "temp_min": -11.13
#     },
#     "name": "Woodward",
#     "sys": {
#         "country": "US",
#         "id": 6275,
#         "sunrise": 1675172397,
#         "sunset": 1675209713,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 2.06
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=sabha
# Processing Record 25 of Set 13 | sabha
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 27.0377,
#         "lon": 14.4283
#     },
#     "dt": 1675175505,
#     "id": 2212775,
#     "main": {
#         "feels_like": 13.74,
#         "grnd_level": 973,
#         "humidity": 20,
#         "pressure": 1023,
#         "sea_level": 1023,
#         "temp": 15.6,
#         "temp_max": 15.6,
#         "temp_min": 15.6
#     },
#     "name": "Sabha",
#     "sys": {
#         "country": "LY",
#         "sunrise": 1675144117,
#         "sunset": 1675183354
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 355,
#         "gust": 4.64,
#         "speed": 4.07
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=kita
# Processing Record 26 of Set 13 | kita
# {
#     "base": "stations",
#     "clouds": {
#         "all": 18
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.0349,
#         "lon": -9.4895
#     },
#     "dt": 1675175506,
#     "id": 2455216,
#     "main": {
#         "feels_like": 32.71,
#         "grnd_level": 974,
#         "humidity": 7,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 35.49,
#         "temp_max": 35.49,
#         "temp_min": 35.49
#     },
#     "name": "Kita",
#     "sys": {
#         "country": "ML",
#         "sunrise": 1675148664,
#         "sunset": 1675190289
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 34,
#         "gust": 1.02,
#         "speed": 1.45
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=matara
# Processing Record 27 of Set 13 | matara
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.9485,
#         "lon": 80.5353
#     },
#     "dt": 1675175507,
#     "id": 1235846,
#     "main": {
#         "feels_like": 25.12,
#         "grnd_level": 1007,
#         "humidity": 85,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 24.4,
#         "temp_max": 24.4,
#         "temp_min": 24.4
#     },
#     "name": "Matara",
#     "sys": {
#         "country": "LK",
#         "sunrise": 1675126510,
#         "sunset": 1675169226
#     },
#     "timezone": 19800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 326,
#         "gust": 4,
#         "speed": 3.1
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=libenge
# Processing Record 28 of Set 13 | libenge
# {
#     "base": "stations",
#     "clouds": {
#         "all": 7
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 3.65,
#         "lon": 18.6333
#     },
#     "dt": 1675175507,
#     "id": 2313762,
#     "main": {
#         "feels_like": 36.02,
#         "grnd_level": 966,
#         "humidity": 19,
#         "pressure": 1005,
#         "sea_level": 1005,
#         "temp": 37.66,
#         "temp_max": 37.66,
#         "temp_min": 37.66
#     },
#     "name": "Libenge",
#     "sys": {
#         "country": "CD",
#         "sunrise": 1675141193,
#         "sunset": 1675184259
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 70,
#         "gust": 4.29,
#         "speed": 2.85
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=hanna
# Processing Record 29 of Set 13 | hanna
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.6334,
#         "lon": -111.9018
#     },
#     "dt": 1675175508,
#     "id": 5970234,
#     "main": {
#         "feels_like": -17.08,
#         "humidity": 87,
#         "pressure": 1007,
#         "temp": -10.08,
#         "temp_max": -10.08,
#         "temp_min": -10.08
#     },
#     "name": "Hanna",
#     "sys": {
#         "country": "CA",
#         "id": 2029594,
#         "sunrise": 1675177683,
#         "sunset": 1675210433,
#         "type": 2
#     },
#     "timezone": -25200,
#     "visibility": 1061,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 284,
#         "gust": 7.15,
#         "speed": 5.36
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=la asuncion
# Processing Record 30 of Set 13 | la asuncion
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 11.0333,
#         "lon": -63.8628
#     },
#     "dt": 1675175509,
#     "id": 3480908,
#     "main": {
#         "feels_like": 26.22,
#         "grnd_level": 1011,
#         "humidity": 66,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 25.86,
#         "temp_max": 25.86,
#         "temp_min": 25.86
#     },
#     "name": "La Asuncion",
#     "sys": {
#         "country": "VE",
#         "sunrise": 1675161556,
#         "sunset": 1675203499
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 79,
#         "gust": 5.84,
#         "speed": 4.17
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=antofagasta
# Processing Record 31 of Set 13 | antofagasta
# {
#     "base": "stations",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.65,
#         "lon": -70.4
#     },
#     "dt": 1675175404,
#     "id": 3899539,
#     "main": {
#         "feels_like": 22.74,
#         "grnd_level": 1011,
#         "humidity": 70,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 22.6,
#         "temp_max": 22.6,
#         "temp_min": 22.6
#     },
#     "name": "Antofagasta",
#     "sys": {
#         "country": "CL",
#         "id": 8488,
#         "sunrise": 1675160372,
#         "sunset": 1675207821,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "gust": 2.22,
#         "speed": 2.69
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=elizabeth city
# Processing Record 32 of Set 13 | elizabeth city
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 36.2946,
#         "lon": -76.2511
#     },
#     "dt": 1675175509,
#     "id": 4465088,
#     "main": {
#         "feels_like": 10.5,
#         "humidity": 99,
#         "pressure": 1024,
#         "temp": 10.78,
#         "temp_max": 11.67,
#         "temp_min": 10
#     },
#     "name": "Elizabeth City",
#     "sys": {
#         "country": "US",
#         "id": 2002902,
#         "sunrise": 1675166830,
#         "sunset": 1675204172,
#         "type": 2
#     },
#     "timezone": -18000,
#     "visibility": 6437,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50d",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 0,
#         "speed": 0
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=luebo
# Processing Record 33 of Set 13 | luebo
# {
#     "base": "stations",
#     "clouds": {
#         "all": 52
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -5.35,
#         "lon": 21.4167
#     },
#     "dt": 1675175510,
#     "id": 210939,
#     "main": {
#         "feels_like": 32.33,
#         "grnd_level": 956,
#         "humidity": 48,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 31.06,
#         "temp_max": 31.06,
#         "temp_min": 31.06
#     },
#     "name": "Luebo",
#     "sys": {
#         "country": "CD",
#         "sunrise": 1675139842,
#         "sunset": 1675184274
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 267,
#         "gust": 2.94,
#         "speed": 1.68
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=rio claro
# Processing Record 34 of Set 13 | rio claro
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -22.4114,
#         "lon": -47.5614
#     },
#     "dt": 1675175304,
#     "id": 3451234,
#     "main": {
#         "feels_like": 25.98,
#         "grnd_level": 944,
#         "humidity": 71,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 25.98,
#         "temp_max": 25.98,
#         "temp_min": 25.98
#     },
#     "name": "Rio Claro",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1675155001,
#         "sunset": 1675202228
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 342,
#         "gust": 5.11,
#         "speed": 3.75
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=shishou
# Processing Record 35 of Set 13 | shishou
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 29.7226,
#         "lon": 112.419
#     },
#     "dt": 1675175511,
#     "id": 1788268,
#     "main": {
#         "feels_like": 10.83,
#         "grnd_level": 1009,
#         "humidity": 34,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 12.62,
#         "temp_max": 12.62,
#         "temp_min": 12.62
#     },
#     "name": "Shishou",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1675120868,
#         "sunset": 1675159562
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 3,
#         "gust": 2.74,
#         "speed": 2.76
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=lasa
# Processing Record 36 of Set 13 | lasa
# {
#     "base": "stations",
#     "clouds": {
#         "all": 26
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.6166,
#         "lon": 10.7002
#     },
#     "dt": 1675174939,
#     "id": 3175096,
#     "main": {
#         "feels_like": 3.94,
#         "grnd_level": 920,
#         "humidity": 58,
#         "pressure": 1023,
#         "sea_level": 1023,
#         "temp": 6.31,
#         "temp_max": 7.05,
#         "temp_min": 6.31
#     },
#     "name": "Laas",
#     "sys": {
#         "country": "IT",
#         "id": 2002891,
#         "sunrise": 1675147379,
#         "sunset": 1675181882,
#         "type": 2
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 318,
#         "gust": 4.12,
#         "speed": 3.2
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=wewak
# Processing Record 37 of Set 13 | wewak
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -3.5534,
#         "lon": 143.6268
#     },
#     "dt": 1675175512,
#     "id": 2083537,
#     "main": {
#         "feels_like": 26.84,
#         "grnd_level": 1008,
#         "humidity": 87,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 25.92,
#         "temp_max": 25.92,
#         "temp_min": 25.92
#     },
#     "name": "Wewak",
#     "sys": {
#         "country": "PG",
#         "sunrise": 1675197059,
#         "sunset": 1675241209
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 278,
#         "gust": 2.31,
#         "speed": 2
#     }
# }
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?appid=35c2e8e1d5c38e17e130271d9d51b48d&units=metric&q=bur gabo
# Processing Record 38 of Set 13 | bur gabo
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# []

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = # YOUR CODE HERE

# Show Record Count
city_data_df.count()

# %%
# Display sample data
city_data_df.head()

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
# YOUR CODE HERE

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
# YOUR CODE HERE

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
# YOUR CODE HERE

# Display sample data
northern_hemi_df.head()

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
# YOUR CODE HERE

# Display sample data
southern_hemi_df.head()

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
# YOUR CODE HERE

# %%
# Linear regression on Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
# YOUR CODE HERE

# %%
# Southern Hemisphere
# YOUR CODE HERE

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
